# %%
import os

path_dir = 'data2_wav/'
file_lists = os.listdir(path_dir)

print(file_lists)
#file_lists.pop(file_lists.index(".DS_Store"))
# Out:
# ['20190819223928.wav', '20190819223900.wav', '20190819223914.wav', '20190819224102.wav', '20190819224107.wav', '20190819223904.wav', '20190819224017.wav', '20190819223816.wav', '20190819223805.wav', '20190819223839.wav', '20190819224037.wav', '20190819223830.wav', '20190819223825.wav', '20190819224032.wav', '20190819223909.wav', '20190819224042.wav', '20190819223933.wav', '20190819224052.wav', '20190819223924.wav', '20190819223919.wav', '20190819223851.wav']

# %%
# -*- coding: utf-8 -*- 
import librosa 
import librosa.display 
import numpy as np 
import matplotlib.pyplot as plt 

frame_length = 0.025 
frame_stride = 0.010 

def wav_to_image(wav_file, save_file):
    # mel-spectrogram 
    y, sr = librosa.load(wav_file, sr=36000) 
    # wav_length = len(y)/sr 
    input_nfft = int(round(sr*frame_length)) 
    input_stride = int(round(sr*frame_stride)) 
    S = librosa.feature.melspectrogram(y=y, n_mels=40, n_fft=input_nfft, hop_length=input_stride) 
    plt.figure(figsize=(10, 5))
    librosa.display.specshow(librosa.power_to_db(S, ref=np.max), sr=sr, hop_length=input_stride)
    plt.subplots_adjust(left=0, bottom=0, right = 1, top = 1, hspace = 0, wspace = 0)
    plt.axis('off'), plt.xticks([]), plt.yticks([])
    plt.savefig('data2_img/' + save_file[:-4]+'.png', bbox_inches='tight', pad_inches=0, dpi=100)

# %%
for file_list in file_lists:
    wav_to_image('data2_wav/' + file_list, file_list)
# Out:
# //anaconda3/envs/venv/lib/python3.6/site-packages/ipykernel_launcher.py:17: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
